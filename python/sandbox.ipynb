# %% [markdown]
# # Predictive Process Monitoring - Data Loading \& Exploration
#
# This notebook is part of the [starter package](https://github.com/fmannhardt/starter-predictive-process-monitoring) for predictive process monitoring. It contains examples for data loading from event logs for the purpose of developing and applying predictive process monitoring techniques.

# %% [markdown]
# ## Setup
# The following Python libraries are used, please refer to the installation instructions to prepare your environment:
#
# * [PM4Py](https://pm4py.fit.fraunhofer.de/)
# * [Pandas](https://pandas.pydata.org/)

# %%
import pandas as pd
import pm4py
from pm4py.objects.log.obj import EventLog, Trace
import zipfile

# %% [markdown]
# ## Event Log
#
# We are using a publicly available event log called Sepsis Cases as an example.

# %% [markdown]
# ### CSV File
# Event logs can be loaded with Pandas from CSV files and are then converted to an event log by PM4Py by specifying columns for the three main requirements of an event log: case identifier, activity identifier, and timestamps.

# %%
zf = zipfile.ZipFile('../data/BPI_Challenge_2017_filtered.zip') 
bpi = pd.read_csv(zf.open('BPI_Challenge_2017.csv'), sep=',')
bpi.head()
# Out:
#                  Case ID              Activity Resource  \
# 0  Application_652823628  A_Create Application   User_1
# 1  Application_652823628           A_Submitted   User_1
# 2  Application_652823628             A_Concept   User_1
# 3  Application_652823628            A_Accepted  User_52
# 4  Application_652823628        O_Create Offer  User_52
#
#            Start Timestamp       Complete Timestamp    Variant  Variant index  \
# 0  2016-01-01 10:51:15.304  2016-01-01 10:51:15.304  Variant 9              9
# 1  2016-01-01 10:51:15.352  2016-01-01 10:51:15.352  Variant 9              9
# 2  2016-01-01 10:52:36.413  2016-01-01 10:52:36.413  Variant 9              9
# 3  2016-01-02 12:23:04.299  2016-01-02 12:23:04.299  Variant 9              9
# 4  2016-01-02 12:29:03.994  2016-01-02 12:29:03.994  Variant 9              9
#
#   lifecycle:transition  EventOrigin                EventID  ...  \
# 0             complete  Application  Application_652823628  ...
# 1             complete  Application   ApplState_1582051990  ...
# 2             complete  Application    ApplState_642383566  ...
# 3             complete  Application     ApplState_99568828  ...
# 4             complete        Offer        Offer_148581083  ...
#
#   ApplicationType RequestedAmount FirstWithdrawalAmount  NumberOfTerms  \
# 0      New credit         20000.0                   NaN            NaN
# 1      New credit         20000.0                   NaN            NaN
# 2      New credit         20000.0                   NaN            NaN
# 3      New credit         20000.0                   NaN            NaN
# 4      New credit         20000.0               20000.0           44.0
#
#    Accepted  MonthlyCost Selected  CreditScore OfferedAmount  OfferID
# 0       NaN          NaN      NaN          NaN           NaN      NaN
# 1       NaN          NaN      NaN          NaN           NaN      NaN
# 2       NaN          NaN      NaN          NaN           NaN      NaN
# 3       NaN          NaN      NaN          NaN           NaN      NaN
# 4      True       498.29     True        979.0       20000.0      NaN
#
# [5 rows x 22 columns]

# %%
bpi_log = pm4py.format_dataframe(bpi, case_id='Case ID', activity_key='Activity', timestamp_key='Start Timestamp')
bpi_log = pm4py.convert_to_event_log(bpi_log)
# Out:
# c:\Users\gianl\anaconda3_2023\envs\Adv_PM\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:180: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# c:\Users\gianl\anaconda3_2023\envs\Adv_PM\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:180: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# c:\Users\gianl\anaconda3_2023\envs\Adv_PM\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:180: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# c:\Users\gianl\anaconda3_2023\envs\Adv_PM\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:180: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# c:\Users\gianl\anaconda3_2023\envs\Adv_PM\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:180: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# c:\Users\gianl\anaconda3_2023\envs\Adv_PM\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:180: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# c:\Users\gianl\anaconda3_2023\envs\Adv_PM\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:180: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# c:\Users\gianl\anaconda3_2023\envs\Adv_PM\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:180: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# c:\Users\gianl\anaconda3_2023\envs\Adv_PM\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:180: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# c:\Users\gianl\anaconda3_2023\envs\Adv_PM\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:180: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# c:\Users\gianl\anaconda3_2023\envs\Adv_PM\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:180: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# c:\Users\gianl\anaconda3_2023\envs\Adv_PM\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:180: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# c:\Users\gianl\anaconda3_2023\envs\Adv_PM\lib\site-packages\pm4py\utils.py:537: UserWarning: the EventLog class has been deprecated and will be removed in a future release.
#   warnings.warn("the EventLog class has been deprecated and will be removed in a future release.")

# %% [markdown]
# Ignore the Pandas warning which is due to some internal issue in PM4Py and let us check if the import succeeded:

# %%
len(bpi)
# Out:
# 70280

# %% [markdown]
# ## Data Exploration
#
# It is a good idea to perform some data exploration to investigate the properties of the event log. Please note that there are much more capabilities in ProM. So, do not limit yourself to using PM4Py.

# %%
# number of distinct trace variants
len(pm4py.get_variants_as_tuples(bpi_log))
# Out:
# 81

# %%
# how does the process start
pm4py.get_start_activities(bpi_log)
# Out:
# {'A_Create Application': 5324}

# %%
# how does the process end
pm4py.get_end_activities(bpi_log)
# Out:
# {'A_Pending': 4394, 'O_Refused': 762, 'O_Cancelled': 168}

# %%
# extract only complete traces 
prefix_traces = []
for trace in bpi_log:
    for i,event in enumerate(trace):
        if "COMPLETE" in event['lifecycle:transition']:
            prefix_traces.append(Trace(trace[:i], attributes = trace.attributes))
    prefix_traces = EventLog(prefix_traces)

# %%
from pm4py.objects.log.util.log import project_traces
def print_nth(log, index):
    print(str(project_traces(prefix_traces)[index]))

# %%
len(prefix_traces)
# Out:
# 475306

# %%
print_nth(prefix_traces, 1)
# Out:
# ['A_Create Application']

# %% [markdown]
# Let us look at the directly-follows graph of the whole event log:

# %%
dfg, start_activities, end_activities = pm4py.discover_dfg(prefix_traces)
pm4py.view_dfg(dfg, start_activities, end_activities)

# %% [markdown]
# A quite messy process. There are countless filtering options in PM4Py that allow you to focus on a subset of the data. For example, what happens if we remove the very frequently repeating activities: Leucocytes, CRP, LacticAcid.

# %%
bpi_log_filtered = pm4py.filter_event_attribute_values(prefix_traces, 
                                    attribute_key = 'concept:name', # special column for the activity name always added by PM4Py
                                    values = ['LacticAcid', 'CRP', 'Leucocytes'], 
                                    level = 'event',    # we want to keep all traces and modify events
                                    retain = False)     # remove matching events
# Out:
# ---------------------------------------------------------------------------
# InvalidVersion                            Traceback (most recent call last)
# /Users/abdalrhman/Documents/starter-predictive-process-monitoring/python/0_data_loading.ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell:/Users/abdalrhman/Documents/starter-predictive-process-monitoring/python/0_data_loading.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> bpi_log_filtered = pm4py.filter_event_attribute_values(bpi_log,
#       <a href='vscode-notebook-cell:/Users/abdalrhman/Documents/starter-predictive-process-monitoring/python/0_data_loading.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a>                                     attribute_key = 'concept:name', # special column for the activity name always added by PM4Py
#       <a href='vscode-notebook-cell:/Users/abdalrhman/Documents/starter-predictive-process-monitoring/python/0_data_loading.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a>                                     values = ['LacticAcid', 'CRP', 'Leucocytes'],
#       <a href='vscode-notebook-cell:/Users/abdalrhman/Documents/starter-predictive-process-monitoring/python/0_data_loading.ipynb#X30sZmlsZQ%3D%3D?line=3'>4</a>                                     level = 'event',    # we want to keep all traces and modify events
#       <a href='vscode-notebook-cell:/Users/abdalrhman/Documents/starter-predictive-process-monitoring/python/0_data_loading.ipynb#X30sZmlsZQ%3D%3D?line=4'>5</a>                                     retain = False)     # remove matching events
#
# File ~/Library/Python/3.9/lib/python/site-packages/pm4py/filtering.py:145, in filter_event_attribute_values(log, attribute_key, values, level, retain)
#     143         return attributes_filter.apply(log, values, parameters=parameters)
#     144 else:
# --> 145     from pm4py.algo.filtering.log.attributes import attributes_filter
#     146     if level == "event":
#     147         parameters[attributes_filter.Parameters.POSITIVE] = retain
#
# File ~/Library/Python/3.9/lib/python/site-packages/pm4py/algo/filtering/log/__init__.py:18
#       1 '''
#       2     This file is part of PM4Py (More Info: https://pm4py.fit.fraunhofer.de).
#       3
#    (...)
#      15     along with PM4Py.  If not, see <https://www.gnu.org/licenses/>.
#      16 '''
# ---> 18 from pm4py.algo.filtering.log import attributes, end_activities, paths, \
#      19     cases, start_activities, timestamp, variants, ltl
#
# File ~/Library/Python/3.9/lib/python/site-packages/pm4py/algo/filtering/log/ltl/__init__.py:17
#       1 '''
#       2     This file is part of PM4Py (More Info: https://pm4py.fit.fraunhofer.de).
#       3
#    (...)
#      15     along with PM4Py.  If not, see <https://www.gnu.org/licenses/>.
#      16 '''
# ---> 17 from pm4py.algo.filtering.log.ltl import ltl_checker
#
# File ~/Library/Python/3.9/lib/python/site-packages/pm4py/algo/filtering/log/ltl/ltl_checker.py:59
#      55             return False
#      56     return True
# ---> 59 @deprecation.deprecated('2.2.6', '3.0.0', 'please use pm4py.algo.filtering.log.ltl.ltl_checker.eventually_follows')
#      60 def A_eventually_B(log, A, B, parameters=None):
#      61     """
#      62     Applies the A eventually B rule
#      63
#    (...)
#      81         Filtered log
#      82     """
#      83     if parameters is None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/deprecation.py:170, in deprecated(deprecated_in, removed_in, current_version, details)
#     168         is_deprecated = True
#     169 elif current_version:
# --> 170     current_version = version.parse(current_version)
#     172     if (removed_in
#     173             and current_version >= version.parse(removed_in)):
#     174         is_unsupported = True
#
# File ~/Library/Python/3.9/lib/python/site-packages/packaging/version.py:52, in parse(version)
#      43 def parse(version: str) -> "Version":
#      44     """Parse the given version string.
#      45
#      46     >>> parse('1.0.dev1')
#    (...)
#      50     :raises InvalidVersion: When the version string is not a valid version.
#      51     """
# ---> 52     return Version(version)
#
# File ~/Library/Python/3.9/lib/python/site-packages/packaging/version.py:197, in Version.__init__(self, version)
#     195 match = self._regex.search(version)
#     196 if not match:
# --> 197     raise InvalidVersion(f"Invalid version: '{version}'")
#     199 # Store the parsed out pieces of the version
#     200 self._version = _Version(
#     201     epoch=int(match.group("epoch")) if match.group("epoch") else 0,
#     202     release=tuple(int(i) for i in match.group("release").split(".")),
#    (...)
#     208     local=_parse_local_version(match.group("local")),
#     209 )
#
# InvalidVersion: Invalid version: 'please use pm4py.algo.filtering.log.ltl.ltl_checker.eventually_follows'

# %%
dfg, start_activities, end_activities = pm4py.discover_dfg(bpi_log_filtered)
pm4py.view_dfg(dfg, start_activities, end_activities)

# %% [markdown]
# A bit more comprehensible but more filtering or pre-processing could be performed, explore the PM4Py documentation on what is possible:
#
# https://pm4py.fit.fraunhofer.de/documentation#filtering
#
# You can also look at the trace or event attributes in an event log to generate suitable subsets.

# %%
pm4py.get_event_attributes(bpi_log)

# %% [markdown]
# The set of values of a specific event attribute can be extracted. A 'nan' indicates that there are many events without such attribute:

# %%
pm4py.get_event_attribute_values(bpi_log, 'Diagnose')
