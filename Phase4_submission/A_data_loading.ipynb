# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import plotly.io as pio
import plotly.express as px
import plotly.graph_objects as go
from pandas.plotting import scatter_matrix
import pm4py
from pm4py.objects.log.util.log import project_traces
from pm4py.objects.log.util import interval_lifecycle
import zipfile

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Trace Analysis & Filtering (PM4PY)
# - https://pm4py.fit.fraunhofer.de/documentation
#
# The imported dataset has already been filtered in Disco as described in the appendix of the report.

# %%
# function to print any trace (index) from log
def print_nth(log, index):
    print(str(project_traces(log)[index]))

# %%
# loading bpi zip (raw log data) and convert to event log object
# read data in csv 
zf = zipfile.ZipFile('../data/BPI_Challenge_2017_filtered.zip') 
bpi = pd.read_csv(zf.open('BPI_Challenge_2017.csv'), sep=',')
bpi_log = pm4py.format_dataframe(bpi, case_id='Case ID', activity_key='Activity', timestamp_key='Start Timestamp')
bpi_log = pm4py.convert_to_event_log(bpi_log)

# %%
# check all starting activities
log_start = pm4py.get_start_activities(bpi_log)
log_start
# Out:
# {'A_Create Application': 12380}

# %%
# number of distinct trace variants
len(pm4py.get_variants_as_tuples(bpi_log))
# Out:
# 107

# %%
# how does the process end
pm4py.get_end_activities(bpi_log)
# Out:
# {'O_Cancelled': 7224, 'A_Pending': 4394, 'O_Refused': 762}

# %%
# print 1st trace
print_nth(bpi_log, 0)
# Out:
# ['A_Create Application', 'A_Submitted', 'A_Concept', 'A_Accepted', 'O_Create Offer', 'O_Created', 'O_Sent (mail and online)', 'A_Complete', 'A_Cancelled', 'O_Cancelled']

# %%
# convert log to dataframe and save
df = pm4py.convert_to_dataframe(bpi_log)
df.head(25)
# Out:
#                    Case ID                  Activity  Resource  \
# 0   Application_1000086665      A_Create Application    User_1
# 1   Application_1000086665               A_Submitted    User_1
# 2   Application_1000086665                 A_Concept    User_1
# 3   Application_1000086665                A_Accepted    User_5
# 4   Application_1000086665            O_Create Offer    User_5
# 5   Application_1000086665                 O_Created    User_5
# 6   Application_1000086665  O_Sent (mail and online)    User_5
# 7   Application_1000086665                A_Complete    User_5
# 8   Application_1000086665               A_Cancelled    User_1
# 9   Application_1000086665               O_Cancelled    User_1
# 10  Application_1000158214      A_Create Application    User_1
# 11  Application_1000158214               A_Submitted    User_1
# 12  Application_1000158214                 A_Concept    User_1
# 13  Application_1000158214    W_Complete application   User_32
# 14  Application_1000158214                A_Accepted   User_32
# 15  Application_1000158214            O_Create Offer   User_32
# 16  Application_1000158214                 O_Created   User_32
# 17  Application_1000158214  O_Sent (mail and online)   User_32
# 18  Application_1000158214                A_Complete   User_32
# 19  Application_1000158214              A_Validating  User_118
# 20  Application_1000158214                O_Returned  User_118
# 21  Application_1000158214                O_Accepted   User_90
# 22  Application_1000158214                 A_Pending   User_90
# 23  Application_1000311556      A_Create Application   User_71
# 24  Application_1000311556    W_Complete application   User_71
#
#                     Start Timestamp               Complete Timestamp  \
# 0  2016-08-03 17:57:21.673000+00:00 2016-08-03 17:57:21.673000+00:00
# 1  2016-08-03 17:57:21.734000+00:00 2016-08-03 17:57:21.734000+00:00
# 2  2016-08-03 17:58:28.299000+00:00 2016-08-03 17:58:28.299000+00:00
# 3  2016-08-05 15:57:07.419000+00:00 2016-08-05 15:57:07.419000+00:00
# 4  2016-08-05 15:59:57.320000+00:00 2016-08-05 15:59:57.320000+00:00
# 5  2016-08-05 15:59:58.162000+00:00 2016-08-05 15:59:58.162000+00:00
# 6  2016-08-05 16:01:23.264000+00:00 2016-08-05 16:01:23.264000+00:00
# 7  2016-08-05 16:01:23.288000+00:00 2016-08-05 16:01:23.288000+00:00
# 8  2016-09-05 08:00:36.710000+00:00 2016-09-05 08:00:36.710000+00:00
# 9  2016-09-05 08:00:36.829000+00:00 2016-09-05 08:00:36.829000+00:00
# 10 2016-06-02 12:14:26.844000+00:00 2016-06-02 12:14:26.844000+00:00
# 11 2016-06-02 12:14:26.885000+00:00 2016-06-02 12:14:26.885000+00:00
# 12 2016-06-02 12:15:36.773000+00:00 2016-06-02 12:15:36.773000+00:00
# 13 2016-06-06 10:02:16.549000+00:00 2016-06-06 10:16:46.869000+00:00
# 14 2016-06-06 10:10:07.694000+00:00 2016-06-06 10:10:07.694000+00:00
# 15 2016-06-06 10:12:02.402000+00:00 2016-06-06 10:12:02.402000+00:00
# 16 2016-06-06 10:12:03.657000+00:00 2016-06-06 10:12:03.657000+00:00
# 17 2016-06-06 10:16:46.835000+00:00 2016-06-06 10:16:46.835000+00:00
# 18 2016-06-06 10:16:46.892000+00:00 2016-06-06 10:16:46.892000+00:00
# 19 2016-06-09 11:54:36.870000+00:00 2016-06-09 11:54:36.870000+00:00
# 20 2016-06-09 11:55:13.652000+00:00 2016-06-09 11:55:13.652000+00:00
# 21 2016-06-10 13:02:01.275000+00:00 2016-06-10 13:02:01.275000+00:00
# 22 2016-06-10 13:02:01.278000+00:00 2016-06-10 13:02:01.278000+00:00
# 23 2016-04-04 17:56:37.675000+00:00 2016-04-04 17:56:37.675000+00:00
# 24 2016-04-04 17:56:37.693000+00:00 2016-04-04 18:15:45.563000+00:00
#
#       Variant  Variant index lifecycle:transition  EventOrigin  \
# 0   Variant 2              2             complete  Application
# 1   Variant 2              2             complete  Application
# 2   Variant 2              2             complete  Application
# 3   Variant 2              2             complete  Application
# 4   Variant 2              2             complete        Offer
# 5   Variant 2              2             complete        Offer
# 6   Variant 2              2             complete        Offer
# 7   Variant 2              2             complete  Application
# 8   Variant 2              2             complete  Application
# 9   Variant 2              2             complete        Offer
# 10  Variant 5              5             complete  Application
# 11  Variant 5              5             complete  Application
# 12  Variant 5              5             complete  Application
# 13  Variant 5              5             complete     Workflow
# 14  Variant 5              5             complete  Application
# 15  Variant 5              5             complete        Offer
# 16  Variant 5              5             complete        Offer
# 17  Variant 5              5             complete        Offer
# 18  Variant 5              5             complete  Application
# 19  Variant 5              5             complete  Application
# 20  Variant 5              5             complete        Offer
# 21  Variant 5              5             complete        Offer
# 22  Variant 5              5             complete  Application
# 23  Variant 3              3             complete  Application
# 24  Variant 3              3             complete     Workflow
#
#                    EventID  ... MonthlyCost Selected CreditScore  \
# 0   Application_1000086665  ...         NaN      NaN         NaN
# 1      ApplState_161925113  ...         NaN      NaN         NaN
# 2      ApplState_385184570  ...         NaN      NaN         NaN
# 3      ApplState_856156982  ...         NaN      NaN         NaN
# 4          Offer_410892064  ...      241.28    False         0.0
# 5    OfferState_2071773136  ...         NaN      NaN         NaN
# 6     OfferState_388269514  ...         NaN      NaN         NaN
# 7     ApplState_1103800866  ...         NaN      NaN         NaN
# 8      ApplState_544389273  ...         NaN      NaN         NaN
# 9    OfferState_1258287612  ...         NaN      NaN         NaN
# 10  Application_1000158214  ...         NaN      NaN         NaN
# 11     ApplState_277536765  ...         NaN      NaN         NaN
# 12    ApplState_1547990892  ...         NaN      NaN         NaN
# 13      Workitem_518835990  ...         NaN      NaN         NaN
# 14     ApplState_226397461  ...         NaN      NaN         NaN
# 15         Offer_927137349  ...      250.00     True       929.0
# 16    OfferState_268883758  ...         NaN      NaN         NaN
# 17   OfferState_1948801867  ...         NaN      NaN         NaN
# 18     ApplState_658801120  ...         NaN      NaN         NaN
# 19    ApplState_1806387445  ...         NaN      NaN         NaN
# 20     OfferState_54186963  ...         NaN      NaN         NaN
# 21    OfferState_974301742  ...         NaN      NaN         NaN
# 22     ApplState_656109704  ...         NaN      NaN         NaN
# 23  Application_1000311556  ...         NaN      NaN         NaN
# 24     Workitem_1256293080  ...         NaN      NaN         NaN
#
#     OfferedAmount          OfferID              concept:name  \
# 0             NaN              NaN      A_Create Application
# 1             NaN              NaN               A_Submitted
# 2             NaN              NaN                 A_Concept
# 3             NaN              NaN                A_Accepted
# 4          5000.0              NaN            O_Create Offer
# 5             NaN  Offer_410892064                 O_Created
# 6             NaN  Offer_410892064  O_Sent (mail and online)
# 7             NaN              NaN                A_Complete
# 8             NaN              NaN               A_Cancelled
# 9             NaN  Offer_410892064               O_Cancelled
# 10            NaN              NaN      A_Create Application
# 11            NaN              NaN               A_Submitted
# 12            NaN              NaN                 A_Concept
# 13            NaN              NaN    W_Complete application
# 14            NaN              NaN                A_Accepted
# 15        12500.0              NaN            O_Create Offer
# 16            NaN  Offer_927137349                 O_Created
# 17            NaN  Offer_927137349  O_Sent (mail and online)
# 18            NaN              NaN                A_Complete
# 19            NaN              NaN              A_Validating
# 20            NaN  Offer_927137349                O_Returned
# 21            NaN  Offer_927137349                O_Accepted
# 22            NaN              NaN                 A_Pending
# 23            NaN              NaN      A_Create Application
# 24            NaN              NaN    W_Complete application
#
#                      time:timestamp  @@index @@case_index  \
# 0  2016-08-03 17:57:21.673000+00:00        0            0
# 1  2016-08-03 17:57:21.734000+00:00        1            0
# 2  2016-08-03 17:58:28.299000+00:00        2            0
# 3  2016-08-05 15:57:07.419000+00:00        3            0
# 4  2016-08-05 15:59:57.320000+00:00        4            0
# 5  2016-08-05 15:59:58.162000+00:00        5            0
# 6  2016-08-05 16:01:23.264000+00:00        6            0
# 7  2016-08-05 16:01:23.288000+00:00        7            0
# 8  2016-09-05 08:00:36.710000+00:00        8            0
# 9  2016-09-05 08:00:36.829000+00:00        9            0
# 10 2016-06-02 12:14:26.844000+00:00       10            1
# 11 2016-06-02 12:14:26.885000+00:00       11            1
# 12 2016-06-02 12:15:36.773000+00:00       12            1
# 13 2016-06-06 10:02:16.549000+00:00       13            1
# 14 2016-06-06 10:10:07.694000+00:00       14            1
# 15 2016-06-06 10:12:02.402000+00:00       15            1
# 16 2016-06-06 10:12:03.657000+00:00       16            1
# 17 2016-06-06 10:16:46.835000+00:00       17            1
# 18 2016-06-06 10:16:46.892000+00:00       18            1
# 19 2016-06-09 11:54:36.870000+00:00       19            1
# 20 2016-06-09 11:55:13.652000+00:00       20            1
# 21 2016-06-10 13:02:01.275000+00:00       21            1
# 22 2016-06-10 13:02:01.278000+00:00       22            1
# 23 2016-04-04 17:56:37.675000+00:00       23            2
# 24 2016-04-04 17:56:37.693000+00:00       24            2
#
#          case:concept:name
# 0   Application_1000086665
# 1   Application_1000086665
# 2   Application_1000086665
# 3   Application_1000086665
# 4   Application_1000086665
# 5   Application_1000086665
# 6   Application_1000086665
# 7   Application_1000086665
# 8   Application_1000086665
# 9   Application_1000086665
# 10  Application_1000158214
# 11  Application_1000158214
# 12  Application_1000158214
# 13  Application_1000158214
# 14  Application_1000158214
# 15  Application_1000158214
# 16  Application_1000158214
# 17  Application_1000158214
# 18  Application_1000158214
# 19  Application_1000158214
# 20  Application_1000158214
# 21  Application_1000158214
# 22  Application_1000158214
# 23  Application_1000311556
# 24  Application_1000311556
#
# [25 rows x 27 columns]

# %% [markdown]
# ## Process Discovery

# %%
# alpha miner - net (places and transactions)
# general way to visualize net or tree or graph in pm4py - pm4py.view_{petri_net/tree/...}
net, initial_marking, final_marking = pm4py.discover_petri_net_alpha(bpi_log)
pm4py.view_petri_net(net)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3_2023\envs\adv_pm\lib\site-packages\graphviz\backend\execute.py:81, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      80     else:
# ---> 81         proc = subprocess.run(cmd, **kwargs)
#      82 except OSError as e:
#
# File ~\anaconda3_2023\envs\adv_pm\lib\subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503     kwargs['stderr'] = PIPE
# --> 505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
#
# File ~\anaconda3_2023\envs\adv_pm\lib\subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#
# File ~\anaconda3_2023\envs\adv_pm\lib\subprocess.py:1436, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1435 try:
# -> 1436     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1437                              # no special security
#    1438                              None, None,
#    1439                              int(not close_fds),
#    1440                              creationflags,
#    1441                              env,
#    1442                              cwd,
#    1443                              startupinfo)
#    1444 finally:
#    1445     # Child is launched. Close the parent's copy of those pipe
#    1446     # handles that only the child should have open.  You need
#    (...)
#    1449     # pipe will not close when the child process exits and the
#    1450     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] Impossibile trovare il file specificato
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# Cell In[9], line 4
#       1 # alpha miner - net (places and transactions)
#       2 # general way to visualize net or tree or graph in pm4py - pm4py.view_{petri_net/tree/...}
#       3 net, initial_marking, final_marking = pm4py.discover_petri_net_alpha(bpi_log)
# ----> 4 pm4py.view_petri_net(net)
#
# File ~\anaconda3_2023\envs\adv_pm\lib\site-packages\pm4py\vis.py:69, in view_petri_net(petri_net, initial_marking, final_marking, format, bgcolor, decorations, debug, rankdir)
#      66 from pm4py.visualization.petri_net import visualizer as pn_visualizer
#      67 gviz = pn_visualizer.apply(petri_net, initial_marking, final_marking,
#      68                            parameters={pn_visualizer.Variants.WO_DECORATION.value.Parameters.FORMAT: format, "bgcolor": bgcolor, "decorations": decorations, "debug": debug, "set_rankdir": rankdir})
# ---> 69 pn_visualizer.view(gviz)
#
# File ~\anaconda3_2023\envs\adv_pm\lib\site-packages\pm4py\visualization\petri_net\visualizer.py:87, in view(gviz, parameters)
#      78 def view(gviz: graphviz.Digraph, parameters=None):
#      79     """
#      80     View the diagram
#      81
#    (...)
#      85         GraphViz diagram
#      86     """
# ---> 87     return gview.view(gviz, parameters=parameters)
#
# File ~\anaconda3_2023\envs\adv_pm\lib\site-packages\pm4py\visualization\common\gview.py:44, in view(gviz, parameters)
#      42     html.view(gviz, parameters=parameters)
#      43 elif vis_utils.check_visualization_inside_jupyter():
# ---> 44     vis_utils.view_image_in_jupyter(gviz.render())
#      45 else:
#      46     return gviz.view(cleanup=True)
#
# File ~\anaconda3_2023\envs\adv_pm\lib\site-packages\graphviz\_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File ~\anaconda3_2023\envs\adv_pm\lib\site-packages\graphviz\rendering.py:122, in Render.render(self, filename, directory, view, cleanup, format, renderer, formatter, neato_no_op, quiet, quiet_view, outfile, engine, raise_if_result_exists, overwrite_source)
#     118 filepath = self.save(filename, directory=directory, skip_existing=None)
#     120 args.append(filepath)
# --> 122 rendered = self._render(*args, **kwargs)
#     124 if cleanup:
#     125     log.debug('delete %r', filepath)
#
# File ~\anaconda3_2023\envs\adv_pm\lib\site-packages\graphviz\_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File ~\anaconda3_2023\envs\adv_pm\lib\site-packages\graphviz\backend\rendering.py:324, in render(engine, format, filepath, renderer, formatter, neato_no_op, quiet, outfile, raise_if_result_exists, overwrite_filepath)
#     320     raise exceptions.FileExistsError(f'output file exists: {os.fspath(outfile)!r}')
#     322 cmd += args
# --> 324 execute.run_check(cmd,
#     325                   cwd=filepath.parent if filepath.parent.parts else None,
#     326                   quiet=quiet,
#     327                   capture_output=True)
#     329 return os.fspath(outfile)
#
# File ~\anaconda3_2023\envs\adv_pm\lib\site-packages\graphviz\backend\execute.py:84, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      82 except OSError as e:
#      83     if e.errno == errno.ENOENT:
# ---> 84         raise ExecutableNotFound(cmd) from e
#      85     raise
#      87 if not quiet and proc.stderr:
#
# ExecutableNotFound: failed to execute WindowsPath('dot'), make sure the Graphviz executables are on your systems' PATH

# %%
# inductive miner algoritham, we can plot perocess tree, and can save the net same as alpha miner ((places and transactions))
net, initial_marking, final_marking = pm4py.discover_petri_net_inductive(bpi_log)
tree = pm4py.discover_process_tree_inductive(bpi_log)
pm4py.view_process_tree(tree)

# %%
# huristic miner
heu_net = pm4py.discover_heuristics_net(bpi_log, dependency_threshold=0.99)
pm4py.view_heuristics_net(heu_net)

# %%
# create and view petri net of huristic miner
net, im, fm = pm4py.discover_petri_net_heuristics(bpi_log, dependency_threshold=0.99)
pm4py.view_petri_net(net, im, fm)

# %%
# plotting directly followes graph
# dfg, start_activities, end_activities = pm4py.discover_dfg(trace_log) # dfg with edge number
performance_dfg, start_activities, end_activities = pm4py.discover_performance_dfg(bpi_log) # dfg with duration
# pm4py.save_vis_performance_dfg(performance_dfg, start_activities, end_activities, 'perf_dfg.svg') # to save image, performance dfg can only be saved and then viewed  
# pm4py.view_dfg(performance_dfg, start_activities, end_activities)

# %% [markdown]
# # Data Analysis (Python)

# %%
# read data in csv 
zf = zipfile.ZipFile('../data/BPI_Challenge_2017_filtered.zip') 
trace = pd.read_csv(zf.open('BPI_Challenge_2017.csv'), sep=',')
trace.head(25)

# %%
# Identify rows where 'O_Create Offer' is followed by 'O_Created' in the 'Activity' column
mask = (trace['Activity'] == 'O_Create Offer') & (trace['Activity'].shift(-1) == 'O_Created')

for i in range(len(mask)-1):
    if ((not mask[i]) & mask[i+1]):
        trace['OfferID'][i+1] = trace['OfferID'][i+2]

# %%
mask = (trace['EventOrigin'] == 'Offer')
eventID = ""
for i in range(len(mask)):
    if (mask[i]):
        if (trace['FirstWithdrawalAmount'][i] > 0):
            FirstWithdrawalAmount = trace['FirstWithdrawalAmount'][i]
            NumberOfTerms = trace['NumberOfTerms'][i]
            Accepted = trace['Accepted'][i]
            MonthlyCost = trace['MonthlyCost'][i]
            Selected = trace['Selected'][i]
            CreditScore = trace['CreditScore'][i] 
            OfferedAmount = trace['OfferedAmount'][i]
            eventID = trace['EventID'][i]
        elif (trace['OfferID'][i] == eventID):
            trace['FirstWithdrawalAmount'][i] = FirstWithdrawalAmount
            trace['NumberOfTerms'][i] = NumberOfTerms 
            trace['Accepted'][i] = Accepted
            trace['MonthlyCost'][i] = MonthlyCost 
            trace['Selected'][i] = Selected 
            trace['CreditScore'][i] = CreditScore 
            trace['OfferedAmount'][i] = OfferedAmount

# %%
trace.head(25)

# %%
# get persentage of missing values in a column
percent_missing = trace.isnull().sum() * 100 / len(trace)
missing_value_df = pd.DataFrame({'column_name': trace.columns,
                                 'percent_missing': percent_missing})

# extract list of coumns which are more then 30%
miss_ls = list(percent_missing[percent_missing>30].keys())

# %%
# save missing val information
# missing_value_df.to_csv('../data/new_missing_vals_bpi.csv',index=False)
# missing_value_df.head()
